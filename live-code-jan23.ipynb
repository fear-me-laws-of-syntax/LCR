# %%
import numpy as np
import pandas as pd

import statsmodels.formula.api as smf
# import statsmodels.api as sm
# import statsmodels.formula.api as smf

import matplotlib.pyplot as plt

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp39-cp39-macosx_11_0_arm64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 7.4 MB/s eta 0:00:01     |██████████████████████████▏     | 8.1 MB 7.4 MB/s eta 0:00:01
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 26.8 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=21.3 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kate/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.15.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
print(sacramento.head())
# Out:
#                street        city    zip state  beds  baths  sq__ft  \
# 0    1 KENNELFORD CIR  SACRAMENTO  95823    CA     3      2    1144
# 1      10 SEA FOAM CT  SACRAMENTO  95831    CA     3      3    2052
# 2      100 CHELSEA CT      FOLSOM  95630    CA     3      2    1905
# 3     100 REBECCA WAY      FOLSOM  95630    CA     3      2    2185
# 4  100 TOURMALINE CIR  SACRAMENTO  95834    CA     5      3    3076
#
#           type                     sale_date   price   latitude   longitude
# 0  Residential  Mon May 19 00:00:00 EDT 2008  200345  38.464520 -121.427606
# 1  Residential  Wed May 21 00:00:00 EDT 2008  415000  38.487885 -121.545947
# 2  Residential  Mon May 19 00:00:00 EDT 2008  500000  38.694350 -121.177259
# 3  Residential  Wed May 21 00:00:00 EDT 2008  344250  38.684790 -121.149199
# 4  Residential  Mon May 19 00:00:00 EDT 2008  240000  38.634370 -121.510779

# %%
import pandas as pd

sacramento = pd.read_csv("01_materials/notebooks/dataset/sacramento.csv")


# Plot the relationship between x and y
plt.scatter(sacramento["sq__ft"], sacramento["price"], label='House size vs House price')

# %%
# Residual plots
fitted = model.fittedvalues
residuals = model.resid


# Homoscedasticity: Residuals vs. Fitted
plt.scatter(fitted, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Residual plots
# ----> 2 fitted = model.fittedvalues
#       3 residuals = model.resid
#       6 # Homoscedasticity: Residuals vs. Fitted
#
# NameError: name 'model' is not defined
